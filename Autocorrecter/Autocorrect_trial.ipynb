# %%
#importing NLTK library
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\chott\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %% [markdown]
# #### Then the first task is to import the text file we will be using to create the word list of correct words.

# %%
# importing regular expression
import re

# words
w = []

# reading text file
with open('final.txt', 'r', encoding="utf8") as f:
    file_name_data = f.read()
    file_name_data = file_name_data.lower()
    w = re.findall('\w+', file_name_data)

# vocabulary
main_set = set(w)

# %% [markdown]
# #### Now we have to count the words and store their frequency. For that we will use dictionary.

# %%
# Functions to count the frequency
# of the words in the whole text file


def counting_words(words):
    word_count = {}
    for word in words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    return word_count

# %% [markdown]
# #### Then to calculate the probability of the words prob_cal function is used.

# %%
# Calculating the probability of each word
def prob_cal(word_count_dict):
    probs = {}
    m = sum(word_count_dict.values())
    for key in word_count_dict.keys():
        probs[key] = word_count_dict[key] / m
    return probs

# %% [markdown]
# #### The further code is divided into 5 main parts, that includes the creation of all types of different words that are possible.

# %% [markdown]
# #### (i) Lemmatization

# %%
pip install pattern
# Out:
# Collecting pattern
#   Downloading Pattern-3.6.0.tar.gz (22.2 MB)
#      ---------------------------------------- 22.2/22.2 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in c:\users\chott\anaconda3\lib\site-packages (from pattern) (0.18.2)
# Collecting backports.csv
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.0-cp39-cp39-win_amd64.whl (200 kB)
#      -------------------------------------- 200.1/200.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in c:\users\chott\anaconda3\lib\site-packages (from pattern) (4.11.1)
# Requirement already satisfied: lxml in c:\users\chott\anaconda3\lib\site-packages (from pattern) (4.9.1)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ---------------------------------------- 81.1/81.1 kB 4.4 MB/s eta 0:00:00
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\chott\anaconda3\lib\site-packages (from pattern) (1.21.5)
# Requirement already satisfied: scipy in c:\users\chott\anaconda3\lib\site-packages (from pattern) (1.9.1)
# Requirement already satisfied: nltk in c:\users\chott\anaconda3\lib\site-packages (from pattern) (3.7)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cherrypy
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      -------------------------------------- 348.4/348.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\chott\anaconda3\lib\site-packages (from pattern) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chott\anaconda3\lib\site-packages (from beautifulsoup4->pattern) (2.3.1)
# Collecting portend>=2.1.1
#   Downloading portend-3.2.0-py3-none-any.whl (5.3 kB)
# Collecting more-itertools
#   Downloading more_itertools-10.1.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB ? eta 0:00:00
# Collecting zc.lockfile
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.6/101.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pywin32>=227 in c:\users\chott\anaconda3\lib\site-packages (from cherrypy->pattern) (302)
# Collecting jaraco.collections
#   Downloading jaraco.collections-4.3.0-py3-none-any.whl (11 kB)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: regex>=2021.8.3 in c:\users\chott\anaconda3\lib\site-packages (from nltk->pattern) (2022.7.9)
# Requirement already satisfied: click in c:\users\chott\anaconda3\lib\site-packages (from nltk->pattern) (8.0.4)
# Requirement already satisfied: joblib in c:\users\chott\anaconda3\lib\site-packages (from nltk->pattern) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\chott\anaconda3\lib\site-packages (from nltk->pattern) (4.64.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\chott\anaconda3\lib\site-packages (from pdfminer.six->pattern) (37.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\chott\anaconda3\lib\site-packages (from pdfminer.six->pattern) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chott\anaconda3\lib\site-packages (from requests->pattern) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chott\anaconda3\lib\site-packages (from requests->pattern) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chott\anaconda3\lib\site-packages (from requests->pattern) (2022.9.14)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.8.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\chott\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.1)
# Collecting tempora>=1.8
#   Downloading tempora-5.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\users\chott\anaconda3\lib\site-packages (from click->nltk->pattern) (0.4.5)
# Collecting jaraco.text
#   Downloading jaraco.text-3.11.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in c:\users\chott\anaconda3\lib\site-packages (from zc.lockfile->cherrypy->pattern) (63.4.1)
# Requirement already satisfied: pycparser in c:\users\chott\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: pytz in c:\users\chott\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2022.1)
# Collecting jaraco.context>=4.1
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting autocommand
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Collecting inflect
#   Downloading inflect-7.0.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions in c:\users\chott\anaconda3\lib\site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (4.3.0)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-2.3.0-py3-none-any.whl (374 kB)
#      -------------------------------------- 374.5/374.5 kB 1.3 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting pydantic-core==2.6.3
#   Downloading pydantic_core-2.6.3-cp39-none-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 2.2 MB/s eta 0:00:00
# Building wheels for collected packages: pattern, python-docx, sgmllib3k
#   Building wheel for pattern (setup.py): started
#   Building wheel for pattern (setup.py): finished with status 'done'
#   Created wheel for pattern: filename=Pattern-3.6-py3-none-any.whl size=22332702 sha256=23593729ad99fa68d16b672bf6310f3b65b3ef865521bf1b7a9204a98bdd6650
#   Stored in directory: c:\users\chott\appdata\local\pip\cache\wheels\50\33\f3\ea00b80d50c09f210588bda15ec60bdb38b289b452577cd5c3
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184489 sha256=870d9147992fad48458e2d6efdcb5f52439f8806ef7f455340e38ebbbe5ef236
#   Stored in directory: c:\users\chott\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=a300a791a8fc9b8a4bd9de104c9b3b8cbfe5f9218287f3975b5531677fee3643
#   Stored in directory: c:\users\chott\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built pattern python-docx sgmllib3k
# Installing collected packages: sgmllib3k, backports.csv, zc.lockfile, typing-extensions, python-docx, mysqlclient, more-itertools, jaraco.context, feedparser, autocommand, annotated-types, pydantic-core, jaraco.functools, tempora, pydantic, pdfminer.six, cheroot, portend, inflect, jaraco.text, jaraco.collections, cherrypy, pattern
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
# Successfully installed annotated-types-0.5.0 autocommand-2.2.2 backports.csv-1.0.7 cheroot-10.0.0 cherrypy-18.8.0 feedparser-6.0.10 inflect-7.0.0 jaraco.collections-4.3.0 jaraco.context-4.3.0 jaraco.functools-3.8.1 jaraco.text-3.11.1 more-itertools-10.1.0 mysqlclient-2.2.0 pattern-3.6 pdfminer.six-20221105 portend-3.2.0 pydantic-2.3.0 pydantic-core-2.6.3 python-docx-0.8.11 sgmllib3k-1.0.0 tempora-5.5.0 typing-extensions-4.7.1 zc.lockfile-3.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
# LemmWord: extracting and adding
# root word i.e.Lemma using pattern module
import pattern
from pattern.en import lemma, lexeme
from nltk.stem import WordNetLemmatizer


def LemmWord(word):
    return list(lexeme(wd) for wd in word.split())[0]

# %% [markdown]
# #### DeleteLetter : Function that Removes a letter from a given word.

# %%
# Deleting letters from the words
def DeleteLetter(word):
    delete_list = []
    split_list = []

    # considering letters 0 to i then i to -1
    # Leaving the ith letter
    for i in range(len(word)):
        split_list.append((word[0:i], word[i:]))

    for a, b in split_list:
        delete_list.append(a + b[1:])
    return delete_list

# %% [markdown]
# #### Switch_ : This function swaps two letters of the word.

# %%
# Switching two letters in a word
def Switch_(word):
    split_list = []
    switch_l = []

    #creating pair of the words(and breaking them)
    for i in range(len(word)):
        split_list.append((word[0:i], word[i:]))
    
    #Printint the first word (i.e. a)
    #then replacing the first and second character of b
    switch_l = [a + b[1] + b[0] + b[2:] for a, b in split_list if len(b) >= 2]
    return switch_l

# %% [markdown]
# #### Replace_ : It changes one letter to another.

# %%
def Replace_(word):
    split_l = []
    replace_list = []

    # Replacing the letter one-by-one from the list of alphs
    for i in range(len(word)):
        split_l.append((word[0:i], word[i:]))
    alphs = 'abcdefghijklmnopqrstuvwxyz'
    replace_list = [a + l + (b[1:] if len(b) > 1 else '')
                    for a, b in split_l if b for l in alphs]
    return replace_list

# %% [markdown]
# #### insert_: It adds additional characters from the bunch of alphabets (one-by-one).

# %%
def insert_(word):
    split_l = []
    insert_list = []

    # Making pairs of the split words
    for i in range(len(word) + 1):
        split_l.append((word[0:i], word[i:]))

    # Storing new words in a list
    # But one new character at each location
    alphs = 'abcdefghijklmnopqrstuvwxyz'
    insert_list = [a + l + b for a, b in split_l for l in alphs]
    return insert_list

# %% [markdown]
# #### Now, we have implemented all the five steps. It’s time to merge all the words (i.e. all functions) formed by those steps.

# %%
# Collecting all the words
# in a set(so that no word will repeat)
def colab_1(word, allow_switches=True):
    colab_1 = set()
    colab_1.update(DeleteLetter(word))
    if allow_switches:
        colab_1.update(Switch_(word))
    colab_1.update(Replace_(word))
    colab_1.update(insert_(word))
    return colab_1

# collecting words using by allowing switches
def colab_2(word, allow_switches=True):
    colab_2 = set()
    edit_one = colab_1(word, allow_switches=allow_switches)
    for w in edit_one:
        if w:
            edit_two = colab_1(w, allow_switches=allow_switches)
            colab_2.update(edit_two)
    return colab_2

# %% [markdown]
# #### Now, The main task is to extract the correct words among all. To do so we will be using a get_corrections function.

# %%
# Only storing those values which are in the vocab
def get_corrections(word, probs, vocab, n=2):
    suggested_word = []
    best_suggestion = []
    suggested_word = list(
        (word in vocab and word) or colab_1(word).intersection(vocab)
        or colab_2(word).intersection(
            vocab))

    # finding out the words with high frequencies
    best_suggestion = [[s, probs[s]] for s in list(reversed(suggested_word))]
    return best_suggestion

# %%
# Input
my_word = input("Enter any word:")

# Counting word function
word_count = counting_words(main_set)

# Calculating probability
probs = prob_cal(word_count)

# only storing correct words
tmp_corrections = get_corrections(my_word, probs, main_set, 2)
for i, word_prob in enumerate(tmp_corrections):
    if(i < 3):
        print(word_prob[0])
    else:
        break
# Out:
# Enter any word:daed
# deed
# daud
# dard

# %%
# Out:
#   File "C:\Users\chott\AppData\Local\Temp\ipykernel_16000\1357955631.py", line 42
#     pip install pattern
#         ^
# SyntaxError: invalid syntax
